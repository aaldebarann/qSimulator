# %%
from qiskit.tools.visualization import plot_histogram

# %%
from qiskit.visualization import plot_histogram

print("s1 - system measure")
counts = {
    "000": 19,
    "001": 24,
    "010": 25,
    "011": 32,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s1: измерение системы")
# Out:
# s1 - system measure

# %%
counts = {
    "000": 25,
    "001": 26,
    "010": 26,
    "011": 23,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s1: измерение кубитов по отдельности")

# %%
counts = {
    "000": 49,
    "001": 0,
    "010": 0,
    "011": 51,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s2: измерение системы")

# %%
counts = {
    "000": 39,
    "001": 0,
    "010": 0,
    "011": 61,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s2: измерение кубитов по отдельности")

# %%
counts = {
    "000": 0,
    "001": 0,
    "010": 47,
    "011": 53,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s3: измерение системы")

# %%
counts = {
    "000": 0,
    "001": 0,
    "010": 52,
    "011": 48,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s3: измерение кубитов по отдельности")

# %%
counts = {
    "000": 0,
    "001": 0,
    "010": 0,
    "011": 0,
    "100": 0,
    "101": 0,
    "110": 46,
    "111": 54,
}
plot_histogram(counts, title="Схема s4: измерение системы")

# %%
counts = {
    "000": 0,
    "001": 0,
    "010": 0,
    "011": 0,
    "100": 0,
    "101": 0,
    "110": 48,
    "111": 52,
}
plot_histogram(counts, title="Схема s4: измерение кубитов по отдельности")

# %%
counts = {
    "000": 47,
    "001": 0,
    "010": 0,
    "011": 0,
    "100": 0,
    "101": 53,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s5: измерение системы")

# %%
counts = {
    "000": 46,
    "001": 0,
    "010": 0,
    "011": 0,
    "100": 0,
    "101": 53,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s5: измерение кубитов по отдельности")

# %%
counts = {
    "000": 0,
    "001": 45,
    "010": 0,
    "011": 0,
    "100": 55,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s6: измерение системы")

# %%
print("s6 - single qubit measure")
counts = {
    "000": 0,
    "001": 52,
    "010": 0,
    "011": 0,
    "100": 48,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s6: измерение кубитов по отдельности")
# Out:
# s6 - single qubit measure

# %%
counts = {
    "000": 0,
    "001": 48,
    "010": 0,
    "011": 0,
    "100": 52,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s7: измерение системы")

# %%
print("s7 - single qubit measure")
counts = {
    "000": 0,
    "001": 48,
    "010": 0,
    "011": 0,
    "100": 52,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s7: измерение кубитов по отдельности")
# Out:
# s7 - single qubit measure

# %%
counts = {
    "000": 100,
    "001": 0,
    "010": 0,
    "011": 0,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s8: измерение системы")

# %%
counts = {
    "000": 100,
    "001": 0,
    "010": 0,
    "011": 0,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s8: измерение кубитов по отдельности")

# %%
counts = {
    "000": 0,
    "001": 50,
    "010": 0,
    "011": 50,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s9: измерение системы")

# %%
counts = {
    "000": 0,
    "001": 54,
    "010": 0,
    "011": 46,
    "100": 0,
    "101": 0,
    "110": 0,
    "111": 0,
}
plot_histogram(counts, title="Схема s9: измерение кубитов по отдельности")
